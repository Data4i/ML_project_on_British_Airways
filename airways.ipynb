# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('british_airways_reviews.csv', index_col = 'id', na_values = ['', ' '])

# %%
df.sample(5)
# Out:
#       Unnamed: 0                  review_header  no_of_reviews  \
# id
# 2216        2216         not be flying BA again              0
# 2157        2157     service is simply terrible              0
# 2566        2566        horrible return flights              2
# 495          495         Absolutely disgraceful              0
# 375          375  can't be reached on the phone              0
#
#        passenger_name country_of_origin                date      is_verified  \
# id
# 2216         G Seeter     United States       16th May 2016  Verified Review
# 2157    Deborah Jones           Bermuda      17th June 2016    not specified
# 2566       N McAvaney         Australia   26th October 2015    not specified
# 495   Adam Bainbridge    United Kingdom  30th December 2020     Not Verified
# 375          A Burran    United Kingdom     11th March 2022    Trip Verified
#
#                                         detailed_review rating_dict.Aircraft  \
# id
# ...

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.sample(5)
# Out:
#                         review_header  no_of_reviews       passenger_name  \
# id
# 3401  British Airways customer review              0            Russ King
# 416    waited for my bags for 3 hours              0           Paul Vella
# 2198    unexpectedly served breakfast              0          Jake Walker
# 133         changed our prepaid seats              0         Derek McLeod
# 3564  British Airways customer review              0  Barry Hebblethwaite
#
#      country_of_origin                date    is_verified  \
# id
# 3401    United Kingdom  1st September 2014  not specified
# 416     United Kingdom  19th December 2021  Trip Verified
# 2198    United Kingdom       23rd May 2016  not specified
# 133     United Kingdom     26th March 2023   Not Verified
# 3564    United Kingdom       4th June 2014  not specified
#
#                                         detailed_review rating_dict.Aircraft  \
# id
# ...

# %%
df.shape
# Out:
# (3642, 20)

# %%
df.isna().sum()
# Out:
# review_header                            0
# no_of_reviews                            0
# passenger_name                           0
# country_of_origin                        4
# date                                     0
# is_verified                              0
# detailed_review                          0
# rating_dict.Aircraft                  1751
# rating_dict.Type Of Traveller          771
# rating_dict.Seat Type                    2
# rating_dict.Route                      775
# rating_dict.Date Flown                 778
# rating_dict.Seat Comfort               111
# rating_dict.Cabin Staff Service        121
# rating_dict.Food & Beverages           374
# rating_dict.Ground Service             844
# rating_dict.Wifi & Connectivity       3056
# rating_dict.Value For Money              0
# rating_dict.Recommended                  0
# rating_dict.Inflight Entertainment    1111
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3642 entries, 0 to 3641
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   review_header                       3642 non-null   object
#  1   no_of_reviews                       3642 non-null   int64
#  2   passenger_name                      3642 non-null   object
#  3   country_of_origin                   3638 non-null   object
#  4   date                                3642 non-null   object
#  5   is_verified                         3642 non-null   object
#  6   detailed_review                     3642 non-null   object
#  7   rating_dict.Aircraft                1891 non-null   object
#  8   rating_dict.Type Of Traveller       2871 non-null   object
#  9   rating_dict.Seat Type               3640 non-null   object
#  10  rating_dict.Route                   2867 non-null   object
# ...
